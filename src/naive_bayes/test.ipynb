# %%
from sklearn.naive_bayes import MultinomialNB
import numpy as np
from matplotlib import pyplot as plt

import sys
sys.path.append("C:\\Users\\Owen\\Documents\\git_projects\\CS534-Project-Team-2")
from src.data_pre_processing import load_data

# %%
X_train, y_train = load_data()
y_train = np.minimum(y_train, 1) # convert all values to 0 or 1
y_train = y_train.ravel() # flatten y_train
X_train += 1 # make all values positive

# %%
mnb = MultinomialNB()

y_pred = mnb.fit(X_train, y_train).predict(X_train)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
plt.plot((y_pred == y_train))

# %%
correct = np.sum(y_pred == y_train) / len(y_train)
false_pos = np.sum((y_pred == 1) & (y_train == 0)) / len(y_train)
false_neg = np.sum((y_pred == 0) & (y_train == 1)) / len(y_train)

print("Accuracy: ", correct)
print("False Positive Rate: ", false_pos)
print("False Negative Rate: ", false_neg)
# Out:
# Accuracy:  0.8212933753943218
# False Positive Rate:  0.027824512209370253
# False Negative Rate:  0.15088211239630797
